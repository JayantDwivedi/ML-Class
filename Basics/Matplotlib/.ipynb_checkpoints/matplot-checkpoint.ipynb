# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.pi
print(x)
# Out:
# 3.141592653589793

# %%
y = np.arange(0,3 * np.pi, 0.1)
print(y)

# %%
plt.plot(x,y)

# %%
plt.hist(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-3e8f0dd4bdf5> in <module>
# ----> 1 plt.hist(x,y)
#
# AttributeError: module 'matplotlib' has no attribute 'hist'
